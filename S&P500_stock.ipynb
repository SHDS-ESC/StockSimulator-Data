# %% [markdown]
# # import library

# %%
import datetime as dt
import pandas as pd
import requests

# %% [markdown]
# # 1. Wiki Pedia 데이터 추출

# %%
# 봇 방지용 헤더
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'

wiki_response = requests.get(url, headers=headers)

if wiki_response.status_code == 200:
    wiki_data = pd.read_html(wiki_response.text)
    print(f"We have a {type(wiki_data)} with length {len(wiki_data)}.")
    print(wiki_data)
else:
    print(f"Error: {wiki_response.status_code}")

# %%
wiki_data[0]
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# 2                           Health Care Equipment  North Chicago, Illinois
# 3                                   Biotechnology  North Chicago, Illinois
# 4                  IT Consulting & Other Services          Dublin, Ireland
# ..                                            ...                      ...
# 498  Industrial Machinery & Supplies & Components   White Plains, New York
# 499                                   Restaurants     Louisville, Kentucky
# 500            Electronic Equipment & Instruments   Lincolnshire, Illinois
# 501                         Health Care Equipment          Warsaw, Indiana
# 502                               Pharmaceuticals   Parsippany, New Jersey
#
#      Date added      CIK      Founded
# 0    1957-03-04    66740         1902
# 1    2017-07-26    91142         1916
# 2    1957-03-04     1800         1888
# 3    2012-12-31  1551152  2013 (1888)
# 4    2011-07-06  1467373         1989
# ..          ...      ...          ...
# 498  2011-11-01  1524472         2011
# 499  1997-10-06  1041061         1997
# 500  2019-12-23   877212         1969
# 501  2001-08-07  1136869         1927
# 502  2013-06-21  1555280         1952
#
# [503 rows x 8 columns]

# %%
wiki_data[0].head()
# Out:
#   Symbol             Security             GICS Sector  \
# 0    MMM                   3M             Industrials
# 1    AOS          A. O. Smith             Industrials
# 2    ABT  Abbott Laboratories             Health Care
# 3   ABBV               AbbVie             Health Care
# 4    ACN            Accenture  Information Technology
#
#                 GICS Sub-Industry    Headquarters Location  Date added  \
# 0        Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1               Building Products     Milwaukee, Wisconsin  2017-07-26
# 2           Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                   Biotechnology  North Chicago, Illinois  2012-12-31
# 4  IT Consulting & Other Services          Dublin, Ireland  2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1    91142         1916
# 2     1800         1888
# 3  1551152  2013 (1888)
# 4  1467373         1989

# %%
wiki_data[1].head()
# Out:
#               Date  Added                      Removed  \
#               Date Ticker             Security  Ticker
# 0  August 28, 2025   IBKR  Interactive Brokers     WBA
# 1    July 23, 2025    XYZ          Block, Inc.     HES
# 2    July 18, 2025    TTD     Trade Desk (The)    ANSS
# 3     July 9, 2025   DDOG              Datadog    JNPR
# 4     May 19, 2025   COIN             Coinbase     DFS
#
#                                                                         Reason
#                    Security                                             Reason
# 0  Walgreens Boots Alliance  Sycamore Partners acquired Walgreen Boots Alli...
# 1          Hess Corporation  S&P 500 and S&P 100 constituent Chevron Corp. ...
# 2                     Ansys  S&P 500 constituent Synopsys Inc. acquired Ans...
# 3          Juniper Networks  S&P 500 constituent Hewlett Packard Enterprise...
# 4        Discover Financial  S&P 500 constituent Capital One Financial Corp...

# %% [markdown]
# # 2. 현재 S&P 500 종목
#
# - Symbol : ticker
# - Security : 종목명
# - GICS Sector : 섹터
# - GICS Sub-Industry : 하위 섹터
# - Headquarters Location
# - Date added
# - CIK : 고유 식별 번호
# - Founded

# %% [markdown]
# GICS는 11개의 주요 섹터로 구성되어 있습니다.
#
# 에너지 (Energy)
#
# 소재 (Materials)
#
# 산업재 (Industrials)
#
# 경기소비재 (Consumer Discretionary)
#
# 필수소비재 (Consumer Staples)
#
# 헬스케어 (Health Care)
#
# 금융 (Financials)
#
# 정보기술 (Information Technology)
#
# 통신서비스 (Communication Services)
#
# 유틸리티 (Utilities)
#
# 부동산 (Real Estate)

# %%
old_cols = list(wiki_data[0].columns)
new_cols = ['ticker', 'security', 'gics_sector', 'gics_sub_industry', 'headquarters_location', 'date_added', 'cik', 'founded']

print(old_cols)
print(new_cols)
# Out:
# ['Symbol', 'Security', 'GICS Sector', 'GICS Sub-Industry', 'Headquarters Location', 'Date added', 'CIK', 'Founded']
# ['ticker', 'security', 'gics_sector', 'gics_sub_industry', 'headquarters_location', 'date_added', 'cik', 'founded']

# %%
wiki_data[0].columns = new_cols
wiki_data[0].head()
# Out:
#   ticker             security             gics_sector  \
# 0    MMM                   3M             Industrials
# 1    AOS          A. O. Smith             Industrials
# 2    ABT  Abbott Laboratories             Health Care
# 3   ABBV               AbbVie             Health Care
# 4    ACN            Accenture  Information Technology
#
#                 gics_sub_industry    headquarters_location  date_added  \
# 0        Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1               Building Products     Milwaukee, Wisconsin  2017-07-26
# 2           Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                   Biotechnology  North Chicago, Illinois  2012-12-31
# 4  IT Consulting & Other Services          Dublin, Ireland  2011-07-06
#
#        cik      founded
# 0    66740         1902
# 1    91142         1916
# 2     1800         1888
# 3  1551152  2013 (1888)
# 4  1467373         1989

# %%
sp500_current = wiki_data[0].copy()
sp500_current.loc[:, 'cik'] = sp500_current['cik'].apply(str).str.zfill(10)
sp500_current.head()
# Out:
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_15340\1434225090.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['0000066740' '0000091142' '0000001800' '0001551152' '0001467373'
#  '0000796343' '0000002488' '0000874761' '0000004977' '0001090872'
#  '0000002969' '0001559720' '0001086222' '0000915913' '0001035443'
#  '0001097149' '0001579241' '0000352541' '0000899051' '0001652044'
#  '0001652044' '0000764180' '0001018724' '0001748790' '0001002910'
#  '0000004904' '0000004962' '0000005272' '0001053507' '0001410636'
#  '0000820027' '0001037868' '0000318154' '0000820313' '0000006281'
#  '0000315293' '0001841666' '0001858681' '0000320193' '0000006951'
  \
# 0        Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1               Building Products     Milwaukee, Wisconsin  2017-07-26
# 2           Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                   Biotechnology  North Chicago, Illinois  2012-12-31
# 4  IT Consulting & Other Services          Dublin, Ireland  2011-07-06
#
#           cik      founded
# 0  0000066740         1902
# 1  0000091142         1916
# 2  0000001800         1888
# 3  0001551152  2013 (1888)
# 4  0001467373         1989

# %% [markdown]
# # 3. 조정 기록
# - 일부 S&P500 편입/퇴출 기록

# %%
sp500_inout = wiki_data[1]
sp500_inout.head()
# Out:
#               Date  Added                      Removed  \
#               Date Ticker             Security  Ticker
# 0  August 28, 2025   IBKR  Interactive Brokers     WBA
# 1    July 23, 2025    XYZ          Block, Inc.     HES
# 2    July 18, 2025    TTD     Trade Desk (The)    ANSS
# 3     July 9, 2025   DDOG              Datadog    JNPR
# 4     May 19, 2025   COIN             Coinbase     DFS
#
#                                                                         Reason
#                    Security                                             Reason
# 0  Walgreens Boots Alliance  Sycamore Partners acquired Walgreen Boots Alli...
# 1          Hess Corporation  S&P 500 and S&P 100 constituent Chevron Corp. ...
# 2                     Ansys  S&P 500 constituent Synopsys Inc. acquired Ans...
# 3          Juniper Networks  S&P 500 constituent Hewlett Packard Enterprise...
# 4        Discover Financial  S&P 500 constituent Capital One Financial Corp...

# %%
sp500_current.columns
# Out:
# Index(['ticker', 'security', 'gics_sector', 'gics_sub_industry',
#        'headquarters_location', 'date_added', 'cik', 'founded'],
#       dtype='object')

# %%
sp500_inout.columns
# Out:
# MultiIndex([(   'Date',     'Date'),
#             (  'Added',   'Ticker'),
#             (  'Added', 'Security'),
#             ('Removed',   'Ticker'),
#             ('Removed', 'Security'),
#             ( 'Reason',   'Reason')],
#            )

# %%
sp500_inout.columns = ['date_modified', 'ticker_added', 'security_added', 'ticker_removed', 'security_removed', 'reason']
sp500_inout.head()
# Out:
#      date_modified ticker_added       security_added ticker_removed  \
# 0  August 28, 2025         IBKR  Interactive Brokers            WBA
# 1    July 23, 2025          XYZ          Block, Inc.            HES
# 2    July 18, 2025          TTD     Trade Desk (The)           ANSS
# 3     July 9, 2025         DDOG              Datadog           JNPR
# 4     May 19, 2025         COIN             Coinbase            DFS
#
#            security_removed                                             reason
# 0  Walgreens Boots Alliance  Sycamore Partners acquired Walgreen Boots Alli...
# 1          Hess Corporation  S&P 500 and S&P 100 constituent Chevron Corp. ...
# 2                     Ansys  S&P 500 constituent Synopsys Inc. acquired Ans...
# 3          Juniper Networks  S&P 500 constituent Hewlett Packard Enterprise...
# 4        Discover Financial  S&P 500 constituent Capital One Financial Corp...

# %%
sp500_added = sp500_inout[~sp500_inout['ticker_added'].isnull()][['date_modified','ticker_added','security_added','reason']]
sp500_added.columns = ['date_modified', 'ticker', 'security', 'reason']
sp500_added['action'] = 'added'
sp500_added.head()
# Out:
#      date_modified ticker             security  \
# 0  August 28, 2025   IBKR  Interactive Brokers
# 1    July 23, 2025    XYZ          Block, Inc.
# 2    July 18, 2025    TTD     Trade Desk (The)
# 3     July 9, 2025   DDOG              Datadog
# 4     May 19, 2025   COIN             Coinbase
#
#                                               reason action
# 0  Sycamore Partners acquired Walgreen Boots Alli...  added
# 1  S&P 500 and S&P 100 constituent Chevron Corp. ...  added
# 2  S&P 500 constituent Synopsys Inc. acquired Ans...  added
# 3  S&P 500 constituent Hewlett Packard Enterprise...  added
# 4  S&P 500 constituent Capital One Financial Corp...  added

# %%
sp500_removed = sp500_inout[~sp500_inout['ticker_removed'].isnull()][['date_modified','ticker_removed','security_removed','reason']]
sp500_removed.columns = ['date_modified', 'ticker', 'security', 'reason']
sp500_removed['action'] = 'removed'
sp500_removed.head()
# Out:
#      date_modified ticker                  security  \
# 0  August 28, 2025    WBA  Walgreens Boots Alliance
# 1    July 23, 2025    HES          Hess Corporation
# 2    July 18, 2025   ANSS                     Ansys
# 3     July 9, 2025   JNPR          Juniper Networks
# 4     May 19, 2025    DFS        Discover Financial
#
#                                               reason   action
# 0  Sycamore Partners acquired Walgreen Boots Alli...  removed
# 1  S&P 500 and S&P 100 constituent Chevron Corp. ...  removed
# 2  S&P 500 constituent Synopsys Inc. acquired Ans...  removed
# 3  S&P 500 constituent Hewlett Packard Enterprise...  removed
# 4  S&P 500 constituent Capital One Financial Corp...  removed

# %%
sp500_history = pd.concat([sp500_added, sp500_removed])
sp500_history[sp500_history.action=='added'].head()
# Out:
#      date_modified ticker             security  \
# 0  August 28, 2025   IBKR  Interactive Brokers
# 1    July 23, 2025    XYZ          Block, Inc.
# 2    July 18, 2025    TTD     Trade Desk (The)
# 3     July 9, 2025   DDOG              Datadog
# 4     May 19, 2025   COIN             Coinbase
#
#                                               reason action
# 0  Sycamore Partners acquired Walgreen Boots Alli...  added
# 1  S&P 500 and S&P 100 constituent Chevron Corp. ...  added
# 2  S&P 500 constituent Synopsys Inc. acquired Ans...  added
# 3  S&P 500 constituent Hewlett Packard Enterprise...  added
# 4  S&P 500 constituent Capital One Financial Corp...  added

# %%
sp500_history[sp500_history.action=='removed'].head()
# Out:
#      date_modified ticker                  security  \
# 0  August 28, 2025    WBA  Walgreens Boots Alliance
# 1    July 23, 2025    HES          Hess Corporation
# 2    July 18, 2025   ANSS                     Ansys
# 3     July 9, 2025   JNPR          Juniper Networks
# 4     May 19, 2025    DFS        Discover Financial
#
#                                               reason   action
# 0  Sycamore Partners acquired Walgreen Boots Alli...  removed
# 1  S&P 500 and S&P 100 constituent Chevron Corp. ...  removed
# 2  S&P 500 constituent Synopsys Inc. acquired Ans...  removed
# 3  S&P 500 constituent Hewlett Packard Enterprise...  removed
# 4  S&P 500 constituent Capital One Financial Corp...  removed

# %%
sp500_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 718 entries, 0 to 375
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date_modified  718 non-null    object
#  1   ticker         718 non-null    object
#  2   security       718 non-null    object
#  3   reason         718 non-null    object
#  4   action         718 non-null    object
# dtypes: object(5)
# memory usage: 33.7+ KB

# %%
sp500_current.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ticker                 503 non-null    object
#  1   security               503 non-null    object
#  2   gics_sector            503 non-null    object
#  3   gics_sub_industry      503 non-null    object
#  4   headquarters_location  503 non-null    object
#  5   date_added             503 non-null    object
#  6   cik                    503 non-null    object
#  7   founded                503 non-null    object
# dtypes: object(8)
# memory usage: 31.6+ KB

# %%
sp500_history_ticker_list = sp500_history.ticker.unique()
len(sp500_history_ticker_list)
# Out:
# 579

# %%
sp500_current_ticker_list = sp500_current.ticker.unique()
len(sp500_current_ticker_list)
# Out:
# 503

# %%
current_ticker_set = set(sp500_current_ticker_list)
history_ticker_set = set(sp500_history_ticker_list)

# 
sub_ticker_set = history_ticker_set - current_ticker_set

# %%
print(len(current_ticker_set), len(history_ticker_set))
# Out:
# 503 579

# %%
len(sub_ticker_set)
# Out:
# 351

# %%
sp500_current.gics_sector.unique()
# Out:
# array(['Industrials', 'Health Care', 'Information Technology',
#        'Utilities', 'Financials', 'Materials', 'Consumer Discretionary',
#        'Real Estate', 'Communication Services', 'Consumer Staples',
#        'Energy'], dtype=object)

# %%
len(sp500_current.gics_sub_industry.unique())
# Out:
# 128

# %%
sp500_current.gics_sub_industry.unique()
# Out:
# array(['Industrial Conglomerates', 'Building Products',
#        'Health Care Equipment', 'Biotechnology',
#        'IT Consulting & Other Services', 'Application Software',
#        'Semiconductors', 'Independent Power Producers & Energy Traders',
#        'Life & Health Insurance', 'Life Sciences Tools & Services',
#        'Industrial Gases', 'Hotels, Resorts & Cruise Lines',
#        'Internet Services & Infrastructure', 'Specialty Chemicals',
#        'Office REITs', 'Health Care Supplies', 'Electric Utilities',
#        'Property & Casualty Insurance', 'Interactive Media & Services',
#        'Tobacco', 'Broadline Retail',
#        'Paper & Plastic Packaging Products & Materials',
#        'Multi-Utilities', 'Consumer Finance', 'Multi-line Insurance',
#        'Telecom Tower REITs', 'Water Utilities',
#        'Asset Management & Custody Banks',
#        'Electrical Components & Equipment', 'Electronic Components',
#        'Insurance Brokers', 'Oil & Gas Exploration & Production',
#        'Technology Hardware, Storage & Peripherals',
#        'Semiconductor Materials & Equipment',
#        'Automotive Parts & Equipment', 'Agricultural Products & Services',
#        'Communications Equipment',
#        'Integrated Telecommunication Services', 'Gas Utilities',
#        'Human Resource & Employment Services', 'Automotive Retail',
#        'Multi-Family Residential REITs', 'Aerospace & Defense',
#        'Oil & Gas Equipment & Services',
#        'Metal, Glass & Plastic Containers', 'Diversified Banks',
#        'Multi-Sector Holdings', 'Computer & Electronics Retail',
#        'Transaction & Payment Processing Services', 'Pharmaceuticals',
#        'Data Processing & Outsourced Services', 'Distillers & Vintners',
#        'Air Freight & Logistics', 'Casinos & Gaming',
#        'Packaged Foods & Meats', 'Health Care Distributors',
#        'Construction Machinery & Heavy Transportation Equipment',
#        'Financial Exchanges & Data', 'Real Estate Services',
#        'Technology Distributors', 'Managed Health Care',
#        'Fertilizers & Agricultural Chemicals',
#        'Investment Banking & Brokerage', 'Cable & Satellite',
#        'Integrated Oil & Gas', 'Restaurants', 'Household Products',
#        'Health Care Services', 'Diversified Support Services',
#        'Regional Banks', 'Soft Drinks & Non-alcoholic Beverages',
#        'Consumer Staples Merchandise Retail', 'Systems Software',
#        'Rail Transportation', 'Footwear', 'Agricultural & Farm Machinery',
#        'Passenger Airlines', 'Data Center REITs',
#        'Specialized Consumer Services',
#        'Industrial Machinery & Supplies & Components',
#        'Commodity Chemicals', 'Homebuilding',
#        'Interactive Home Entertainment', 'Research & Consulting Services',
#        'Personal Care Products', 'Reinsurance', 'Self-Storage REITs',
#        'Trading Companies & Distributors', 'Retail REITs',
#        'Automobile Manufacturers', 'Broadcasting', 'Copper',
#        'Consumer Electronics', 'Heavy Electrical Equipment',
#        'Distributors', 'Leisure Products', 'Health Care Facilities',
#        'Health Care REITs', 'Home Improvement Retail',
#        'Hotel & Resort REITs', 'Advertising',
#        'Single-Family Residential REITs', 'Other Specialized REITs',
#        'Cargo Ground Transportation', 'Electronic Manufacturing Services',
#        'Construction & Engineering', 'Electronic Equipment & Instruments',
#        'Oil & Gas Storage & Transportation', 'Food Retail',
#        'Movies & Entertainment', 'Apparel, Accessories & Luxury Goods',
#        'Oil & Gas Refining & Marketing', 'Construction Materials',
#        'Home Furnishings', 'Brewers', 'Gold', 'Publishing', 'Steel',
#        'Industrial REITs', 'Environmental & Facilities Services',
#        'Apparel Retail', 'Health Care Technology', 'Food Distributors',
#        'Wireless Telecommunication Services', 'Other Specialty Retail',
#        'Passenger Ground Transportation', 'Timber REITs',
#        'Homefurnishing Retail'], dtype=object)

# %%
print(sp500_current.groupby('gics_sector')['gics_sub_industry'])
# Out:
# <pandas.core.groupby.generic.SeriesGroupBy object at 0x0000020EFBEFA350>

# %%
sp500_current.groupby('gics_sector')['gics_sub_industry'].unique()
# Out:
# gics_sector
# Communication Services    [Interactive Media & Services, Integrated Tele...
# Consumer Discretionary    [Hotels, Resorts & Cruise Lines, Broadline Ret...
# Consumer Staples          [Tobacco, Agricultural Products & Services, Di...
# Energy                    [Oil & Gas Exploration & Production, Oil & Gas...
# Financials                [Life & Health Insurance, Property & Casualty ...
# Health Care               [Health Care Equipment, Biotechnology, Life Sc...
# Industrials               [Industrial Conglomerates, Building Products, ...
# Information Technology    [IT Consulting & Other Services, Application S...
# Materials                 [Industrial Gases, Specialty Chemicals, Paper ...
# Real Estate               [Office REITs, Telecom Tower REITs, Multi-Fami...
# Utilities                 [Independent Power Producers & Energy Traders,...
# Name: gics_sub_industry, dtype: object

# %%
gics_sector = sp500_current.groupby('gics_sector')['gics_sub_industry'].apply(list)

# %%
gics_sector.index
# Out:
# Index(['Communication Services', 'Consumer Discretionary', 'Consumer Staples',
#        'Energy', 'Financials', 'Health Care', 'Industrials',
#        'Information Technology', 'Materials', 'Real Estate', 'Utilities'],
#       dtype='object', name='gics_sector')

# %%
gics_sector.loc['Information Technology']
# Out:
# ['IT Consulting & Other Services',
#  'Application Software',
#  'Semiconductors',
#  'Internet Services & Infrastructure',
#  'Electronic Components',
#  'Semiconductors',
#  'Technology Hardware, Storage & Peripherals',
#  'Semiconductor Materials & Equipment',
#  'Communications Equipment',
#  'Application Software',
#  'Semiconductors',
#  'Application Software',
#  'Technology Distributors',
#  'Communications Equipment',
#  'IT Consulting & Other Services',
#  'Electronic Components',
#  'Systems Software',
#  'Application Software',
#  'Technology Hardware, Storage & Peripherals',
#  'Semiconductor Materials & Equipment',
#  'IT Consulting & Other Services',
#  'Communications Equipment',
#  'Application Software',
#  'Semiconductors',
#  'Systems Software',
#  'IT Consulting & Other Services',
#  'Systems Software',
#  'Internet Services & Infrastructure',
#  'Technology Hardware, Storage & Peripherals',
#  'Technology Hardware, Storage & Peripherals',
#  'IT Consulting & Other Services',
#  'Semiconductors',
#  'Application Software',
#  'Electronic Manufacturing Services',
#  'Electronic Equipment & Instruments',
#  'Semiconductor Materials & Equipment',
#  'Semiconductor Materials & Equipment',
#  'Semiconductors',
#  'Semiconductors',
#  'Systems Software',
#  'Semiconductors',
#  'Communications Equipment',
#  'Technology Hardware, Storage & Peripherals',
#  'Semiconductors',
#  'Semiconductors',
#  'Semiconductors',
#  'Application Software',
#  'Application Software',
#  'Systems Software',
#  'Application Software',
#  'Semiconductors',
#  'Electronic Equipment & Instruments',
#  'Application Software',
#  'Technology Hardware, Storage & Peripherals',
#  'Systems Software',
#  'Semiconductors',
#  'Technology Hardware, Storage & Peripherals',
#  'Application Software',
#  'Electronic Manufacturing Services',
#  'Electronic Equipment & Instruments',
#  'Semiconductor Materials & Equipment',
#  'Semiconductors',
#  'Electronic Equipment & Instruments',
#  'Application Software',
#  'Internet Services & Infrastructure',
#  'Technology Hardware, Storage & Peripherals',
#  'Application Software',
#  'Electronic Equipment & Instruments']
