# %%
import datetime as dt
import pandas as pd
import requests

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = pd.read_html(response.text)
    print(f"We have a {type(data)} with length {len(data)}.")
    print(data)
else:
    print(f"Error: {response.status_code}")
# Out:
# We have a <class 'list'> with length 2.
# [    Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
data[0].head()
# Out:
#   Symbol             Security             GICS Sector  \
# 0    MMM                   3M             Industrials
# 1    AOS          A. O. Smith             Industrials
# 2    ABT  Abbott Laboratories             Health Care
# 3   ABBV               AbbVie             Health Care
# 4    ACN            Accenture  Information Technology
#
#                 GICS Sub-Industry    Headquarters Location  Date added  \
# 0        Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1               Building Products     Milwaukee, Wisconsin  2017-07-26
# 2           Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                   Biotechnology  North Chicago, Illinois  2012-12-31
# 4  IT Consulting & Other Services          Dublin, Ireland  2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1    91142         1916
# 2     1800         1888
# 3  1551152  2013 (1888)
# 4  1467373         1989

# %%
data[1].head()
# Out:
#               Date  Added                      Removed  \
#               Date Ticker             Security  Ticker
# 0  August 28, 2025   IBKR  Interactive Brokers     WBA
# 1    July 23, 2025    XYZ          Block, Inc.     HES
# 2    July 18, 2025    TTD     Trade Desk (The)    ANSS
# 3     July 9, 2025   DDOG              Datadog    JNPR
# 4     May 19, 2025   COIN             Coinbase     DFS
#
#                                                                         Reason
#                    Security                                             Reason
# 0  Walgreens Boots Alliance  Sycamore Partners acquired Walgreen Boots Alli...
# 1          Hess Corporation  S&P 500 and S&P 100 constituent Chevron Corp. ...
# 2                     Ansys  S&P 500 constituent Synopsys Inc. acquired Ans...
# 3          Juniper Networks  S&P 500 constituent Hewlett Packard Enterprise...
# 4        Discover Financial  S&P 500 constituent Capital One Financial Corp...

# %% [markdown]
# # 2. Get Current S&P Members

# %%
sp500 = data[0].loc[:, ['Symbol', 'Security', 'Date added', 'CIK']]
sp500.head()
# Out:
#   Symbol             Security  Date added      CIK
# 0    MMM                   3M  1957-03-04    66740
# 1    AOS          A. O. Smith  2017-07-26    91142
# 2    ABT  Abbott Laboratories  1957-03-04     1800
# 3   ABBV               AbbVie  2012-12-31  1551152
# 4    ACN            Accenture  2011-07-06  1467373

# %%
sp500.columns = ['ticker', 'name', 'date', 'cik']
sp500.head()
# Out:
#   ticker                 name        date      cik
# 0    MMM                   3M  1957-03-04    66740
# 1    AOS          A. O. Smith  2017-07-26    91142
# 2    ABT  Abbott Laboratories  1957-03-04     1800
# 3   ABBV               AbbVie  2012-12-31  1551152
# 4    ACN            Accenture  2011-07-06  1467373

# %%
sp500[sp500.date.isnull()]
# Out:
# Empty DataFrame
# Columns: [ticker, name, date, cik]
# Index: []

# %%
sp500.date.unique()
# Out:
# array(['1957-03-04', '2017-07-26', '2012-12-31', '2011-07-06',
#        '1997-05-05', '2017-03-20', '1998-10-02', '1999-05-28',
#        '2000-06-05', '1985-04-30', '2023-09-18', '2007-07-12',
#        '2016-07-01', '2017-06-19', '2013-12-02', '1995-07-13',
#        '2014-04-03', '2006-04-03', '2005-11-18', '2019-06-07',
#        '1991-09-19', '1976-06-30', '1980-03-31', '2007-11-19',
#        '2016-03-04', '2005-10-03', '2013-09-23', '1992-01-02',
#        '2008-09-30', '1999-10-12', '1996-04-23', '1997-07-28',
#        '2024-12-23', '1982-11-30', '1995-03-16', '2012-12-24',
#        '2022-11-01', '2018-08-28', '2016-05-31', '2007-04-10',
#        '1983-11-30', '2019-02-15', '1989-12-01', '1981-03-31',
#        '1997-01-02', '2007-01-10', '1987-12-31', '2023-05-04',
#        '2017-07-07', '1984-10-31', '1972-09-30', '2010-02-16',
#        '1999-06-29', '2021-08-30', '2003-11-13', '2011-04-04',
#        '2025-07-23', '1995-03-31', '2009-11-06', '1995-02-24',
# ...

# %%
len(sp500.date.unique())
# Out:
# 374

# %%
current = sp500.copy()
current.loc[:, 'cik'] = current['cik'].apply(str).str.zfill(10)
current.head(10)
# Out:
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\3122067434.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['0000066740' '0000091142' '0000001800' '0001551152' '0001467373'
#  '0000796343' '0000002488' '0000874761' '0000004977' '0001090872'
#  '0000002969' '0001559720' '0001086222' '0000915913' '0001035443'
#  '0001097149' '0001579241' '0000352541' '0000899051' '0001652044'
#  '0001652044' '0000764180' '0001018724' '0001748790' '0001002910'
#  '0000004904' '0000004962' '0000005272' '0001053507' '0001410636'
#  '0000820027' '0001037868' '0000318154' '0000820313' '0000006281'
#  '0000315293' '0001841666' '0001858681' '0000320193' '0000006951'
#  '0001521332' '0000947484' '0000007084' '0001596532' '0000354190'
#  '0001267238' '0000732717' '0000731802' '0000769397' '0000008670'
#  '0000866787' '0000915912' '0000008818' '0001069183' '0001701605'
# ...

# %% [markdown]
# 현재 데이터에는 'Added Date' 가 NaN 으로 표기된 데이터가 존재하지 않는다.

# %% [markdown]
# # 3. Manage Adjustments

# %%
adjustments = data[1]
adjustments.head()
# Out:
#               Date  Added                      Removed  \
#               Date Ticker             Security  Ticker
# 0  August 28, 2025   IBKR  Interactive Brokers     WBA
# 1    July 23, 2025    XYZ          Block, Inc.     HES
# 2    July 18, 2025    TTD     Trade Desk (The)    ANSS
# 3     July 9, 2025   DDOG              Datadog    JNPR
# 4     May 19, 2025   COIN             Coinbase     DFS
#
#                                                                         Reason
#                    Security                                             Reason
# 0  Walgreens Boots Alliance  Sycamore Partners acquired Walgreen Boots Alli...
# 1          Hess Corporation  S&P 500 and S&P 100 constituent Chevron Corp. ...
# 2                     Ansys  S&P 500 constituent Synopsys Inc. acquired Ans...
# 3          Juniper Networks  S&P 500 constituent Hewlett Packard Enterprise...
# 4        Discover Financial  S&P 500 constituent Capital One Financial Corp...

# %%
columns = ['date', 'ticker_added', 'name_added', 'ticker_removed', 'name_removed', 'reason']
adjustments.columns = columns
adjustments.head()
# Out:
#               date ticker_added           name_added ticker_removed  \
# 0  August 28, 2025         IBKR  Interactive Brokers            WBA
# 1    July 23, 2025          XYZ          Block, Inc.            HES
# 2    July 18, 2025          TTD     Trade Desk (The)           ANSS
# 3     July 9, 2025         DDOG              Datadog           JNPR
# 4     May 19, 2025         COIN             Coinbase            DFS
#
#                name_removed                                             reason
# 0  Walgreens Boots Alliance  Sycamore Partners acquired Walgreen Boots Alli...
# 1          Hess Corporation  S&P 500 and S&P 100 constituent Chevron Corp. ...
# 2                     Ansys  S&P 500 constituent Synopsys Inc. acquired Ans...
# 3          Juniper Networks  S&P 500 constituent Hewlett Packard Enterprise...
# 4        Discover Financial  S&P 500 constituent Capital One Financial Corp...

# %%
adjustments.isnull().sum()
# Out:
# date               0
# ticker_added      15
# name_added        15
# ticker_removed    19
# name_removed      19
# reason             0
# dtype: int64

# %%
adjustments[adjustments['ticker_removed'].isnull()]
# Out:
#                    date ticker_added                        name_added  \
# 14   September 30, 2024         AMTM                           Amentum
# 24        April 2, 2024          GEV                        GE Vernova
# 25        April 1, 2024         SOLV                         Solventum
# 34      October 2, 2023         VLTO                           Veralto
# 44      January 4, 2023         GEHC                     GE HealthCare
# 48    December 15, 2022          MBC                       MasterBrand
# 65     February 2, 2022          CEG              Constellation Energy
# 76         June 3, 2021          OGN                     Organon & Co.
# 88      October 9, 2020          VNT                           Vontier
# 101       April 3, 2020         OTIS                    Otis Worldwide
# 102       April 3, 2020         CARR                           Carrier
# 200       April 8, 2016           UA            Under Armour (Class C)
# ...

# %%
len(adjustments)
# Out:
# 376

# %%
adjustments['ticker_added'].isnull().sum()
# Out:
# np.int64(15)

# %%
additions = adjustments[~adjustments['ticker_added'].isnull()][['date','ticker_added', 'name_added']]
additions.columns = ['date','ticker','name']
additions['action'] = 'added'
additions
# Out:
#                    date ticker                           name action
# 0       August 28, 2025   IBKR            Interactive Brokers  added
# 1         July 23, 2025    XYZ                    Block, Inc.  added
# 2         July 18, 2025    TTD               Trade Desk (The)  added
# 3          July 9, 2025   DDOG                        Datadog  added
# 4          May 19, 2025   COIN                       Coinbase  added
# ..                  ...    ...                            ...    ...
# 371   December 11, 1998   CPWR                      Compuware  added
# 372       June 17, 1997    CCI  Countrywide Credit Industries  added
# 373  September 30, 1994    NCC                  National City  added
# 374        July 1, 1976    BUD                 Anheuser Busch  added
# 375        July 1, 1976    DIS        The Walt Disney Company  added
#
# [361 rows x 4 columns]

# %%
adjustments['ticker_removed'].isnull().sum()
# Out:
# np.int64(19)

# %%
removals = adjustments[~adjustments['ticker_removed'].isnull()][['date','ticker_removed','name_removed']]
removals.columns = ['date','ticker','name']
removals['action'] = 'removed'
removals
# Out:
#                    date ticker                      name   action
# 0       August 28, 2025    WBA  Walgreens Boots Alliance  removed
# 1         July 23, 2025    HES          Hess Corporation  removed
# 2         July 18, 2025   ANSS                     Ansys  removed
# 3          July 9, 2025   JNPR          Juniper Networks  removed
# 4          May 19, 2025    DFS        Discover Financial  removed
# ..                  ...    ...                       ...      ...
# 371   December 11, 1998    SUN                SunAmerica  removed
# 372       June 17, 1997    USL                    USLife  removed
# 373  September 30, 1994    MCK                  McKesson  removed
# 374        July 1, 1976    HNG       Houston Natural Gas  removed
# 375        July 1, 1976    AYE          Allegheny Energy  removed
#
# [357 rows x 4 columns]

# %%
historical = pd.concat([additions, removals])
historical
# Out:
#                    date ticker                 name   action
# 0       August 28, 2025   IBKR  Interactive Brokers    added
# 1         July 23, 2025    XYZ          Block, Inc.    added
# 2         July 18, 2025    TTD     Trade Desk (The)    added
# 3          July 9, 2025   DDOG              Datadog    added
# 4          May 19, 2025   COIN             Coinbase    added
# ..                  ...    ...                  ...      ...
# 371   December 11, 1998    SUN           SunAmerica  removed
# 372       June 17, 1997    USL               USLife  removed
# 373  September 30, 1994    MCK             McKesson  removed
# 374        July 1, 1976    HNG  Houston Natural Gas  removed
# 375        July 1, 1976    AYE     Allegheny Energy  removed
#
# [718 rows x 4 columns]

# %%
historical.date = pd.to_datetime(historical.date)
historical
# Out:
#           date ticker                 name   action
# 0   2025-08-28   IBKR  Interactive Brokers    added
# 1   2025-07-23    XYZ          Block, Inc.    added
# 2   2025-07-18    TTD     Trade Desk (The)    added
# 3   2025-07-09   DDOG              Datadog    added
# 4   2025-05-19   COIN             Coinbase    added
# ..         ...    ...                  ...      ...
# 371 1998-12-11    SUN           SunAmerica  removed
# 372 1997-06-17    USL               USLife  removed
# 373 1994-09-30    MCK             McKesson  removed
# 374 1976-07-01    HNG  Houston Natural Gas  removed
# 375 1976-07-01    AYE     Allegheny Energy  removed
#
# [718 rows x 4 columns]

# %% [markdown]
# # 4. Merge Missing Tickers

# %%
missing = current[~current['ticker'].isin(historical['ticker'])].copy()
missing
# Out:
#     ticker                  name        date         cik
# 0      MMM                    3M  1957-03-04  0000066740
# 2      ABT   Abbott Laboratories  1957-03-04  0000001800
# 5     ADBE            Adobe Inc.  1997-05-05  0000796343
# 7      AES       AES Corporation  1998-10-02  0000874761
# 8      AFL                 Aflac  1999-05-28  0000004977
# ..     ...                   ...         ...         ...
# 494    WTW  Willis Towers Watson  2016-01-05  0001140536
# 496   WYNN          Wynn Resorts  2008-11-14  0001174922
# 497    XEL           Xcel Energy  1957-03-04  0000072903
# 499    YUM           Yum! Brands  1997-10-06  0001041061
# 501    ZBH         Zimmer Biomet  2001-08-07  0001136869
#
# [275 rows x 4 columns]

# %%
missing['action'] = 'added'
missing = missing[['date','ticker','name','action', 'cik']]
missing
# Out:
#            date ticker                  name action         cik
# 0    1957-03-04    MMM                    3M  added  0000066740
# 2    1957-03-04    ABT   Abbott Laboratories  added  0000001800
# 5    1997-05-05   ADBE            Adobe Inc.  added  0000796343
# 7    1998-10-02    AES       AES Corporation  added  0000874761
# 8    1999-05-28    AFL                 Aflac  added  0000004977
# ..          ...    ...                   ...    ...         ...
# 494  2016-01-05    WTW  Willis Towers Watson  added  0001140536
# 496  2008-11-14   WYNN          Wynn Resorts  added  0001174922
# 497  1957-03-04    XEL           Xcel Energy  added  0000072903
# 499  1997-10-06    YUM           Yum! Brands  added  0001041061
# 501  2001-08-07    ZBH         Zimmer Biomet  added  0001136869
#
# [275 rows x 5 columns]

# %%
historical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 718 entries, 0 to 375
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    718 non-null    datetime64[ns]
#  1   ticker  718 non-null    object
#  2   name    718 non-null    object
#  3   action  718 non-null    object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 28.0+ KB

# %%
missing.date = pd.to_datetime(missing.date)
missing
# Out:
#           date ticker                  name action         cik
# 0   1957-03-04    MMM                    3M  added  0000066740
# 2   1957-03-04    ABT   Abbott Laboratories  added  0000001800
# 5   1997-05-05   ADBE            Adobe Inc.  added  0000796343
# 7   1998-10-02    AES       AES Corporation  added  0000874761
# 8   1999-05-28    AFL                 Aflac  added  0000004977
# ..         ...    ...                   ...    ...         ...
# 494 2016-01-05    WTW  Willis Towers Watson  added  0001140536
# 496 2008-11-14   WYNN          Wynn Resorts  added  0001174922
# 497 1957-03-04    XEL           Xcel Energy  added  0000072903
# 499 1997-10-06    YUM           Yum! Brands  added  0001041061
# 501 2001-08-07    ZBH         Zimmer Biomet  added  0001136869
#
# [275 rows x 5 columns]

# %%
missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 275 entries, 0 to 501
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    275 non-null    datetime64[ns]
#  1   ticker  275 non-null    object
#  2   name    275 non-null    object
#  3   action  275 non-null    object
#  4   cik     275 non-null    object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 12.9+ KB

# %%
sp500_history = pd.concat([historical, missing], ignore_index=True)
sp500_history = sp500_history.sort_values(by=['date','ticker'], ascending=[False, True])
sp500_history
# Out:
#           date ticker                       name   action         cik
# 0   2025-08-28   IBKR        Interactive Brokers    added         NaN
# 361 2025-08-28    WBA   Walgreens Boots Alliance  removed         NaN
# 362 2025-07-23    HES           Hess Corporation  removed         NaN
# 1   2025-07-23    XYZ                Block, Inc.    added         NaN
# 363 2025-07-18   ANSS                      Ansys  removed         NaN
# ..         ...    ...                        ...      ...         ...
# 952 1957-03-04     SO           Southern Company    added  0000092122
# 944 1957-03-04   SPGI                 S&P Global    added  0000064040
# 970 1957-03-04    UNP  Union Pacific Corporation    added  0000100885
# 990 1957-03-04    XEL                Xcel Energy    added  0000072903
# 824 1957-03-04    XOM                 ExxonMobil    added  0000034088
#
# [993 rows x 5 columns]

# %%
sp500_history.date = sp500_history.date.dt.date

# %%
sp500_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 993 entries, 0 to 824
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    993 non-null    object
#  1   ticker  993 non-null    object
#  2   name    993 non-null    object
#  3   action  993 non-null    object
#  4   cik     275 non-null    object
# dtypes: object(5)
# memory usage: 46.5+ KB

# %%
sp500_history.head()
# Out:
#            date ticker                      name   action  cik
# 0    2025-08-28   IBKR       Interactive Brokers    added  NaN
# 361  2025-08-28    WBA  Walgreens Boots Alliance  removed  NaN
# 362  2025-07-23    HES          Hess Corporation  removed  NaN
# 1    2025-07-23    XYZ               Block, Inc.    added  NaN
# 363  2025-07-18   ANSS                     Ansys  removed  NaN

# %% [markdown]
# # 5. Export

# %%
today = dt.datetime.today().strftime('%Y-%m-%d')
today
# Out:
# '2025-09-03'

# %%
current.to_csv(f"{today}-sp500.csv")
sp500_history.to_csv(f"{today}-sp500_history.csv")

# %% [markdown]
# # To SQL

# %%
# !pip install pandas sqlalchemy mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------------------------- ---------- 1.6/2.1 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 6.2 MB/s  0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
# ...

# %%
from sqlalchemy import create_engine
import mysql.connector

db_url = 'mysql+mysqlconnector://testuser:test1234@localhost/stock_simul'
engine = create_engine(db_url)

try:
    sp500_history.to_sql(name='snp_history', con=engine, if_exists='replace', index=False)
    print("Success")
except Exception as e:
    print(f"Error... : {e}")
# Out:
# Success

# %%
def ToSQL(df, table_name):
    try:
        df.to_sql(name=table_name, con=engine, if_exists='replace', index=False)
        print("Success")
    except Exception as e:
        print(f"Error... : {e}")

# %%
ToSQL(stock_history3, engine, 'stock_history')
# Out:
# Success: 'stock_history' 테이블에 데이터가 성공적으로 저장되었습니다.

# %%
def ToSQL(df: pd.DataFrame, engine: create_engine, table_name: str, if_exists: str = 'replace'):
    """
    Pandas DataFrame을 SQL 데이터베이스 테이블에 저장합니다.
    트랜잭션을 안전하게 관리하여 오류를 방지합니다.

    Args:
        df (pd.DataFrame): 저장할 DataFrame
        engine (create_engine): SQLAlchemy 데이터베이스 엔진
        table_name (str): 데이터를 저장할 테이블 이름
        if_exists (str): 테이블 존재 시 처리 방법 ('fail', 'replace', 'append')
    """
    try:
        # with 구문을 사용하여 연결과 트랜잭션을 안전하게 관리
        with engine.connect() as conn:
            with conn.begin() as transaction:
                # 데이터 삽입
                df.to_sql(name=table_name, con=conn, if_exists=if_exists, index=False, chunksize=10000)
        
        print(f"Success: '{table_name}' 테이블에 데이터가 성공적으로 저장되었습니다.")
    
    except Exception as e:
        print(f"Error... : {e}")
        # with conn.begin()이 오류를 감지하면 자동으로 롤백을 수행합니다.
        # 따라서 명시적인 transaction.rollback() 호출은 필요하지 않습니다.

# %% [markdown]
# # 테스트

# %%
sp500_history[sp500_history.ticker=='GOOGL']
# Out:
#               date ticker    name action  cik
# 252  April 3, 2014  GOOGL  Google  added  NaN

# %%
missing[missing.ticker=='GOOG']
# Out:
#           date ticker                     name action         cik
# 20  2006-04-03   GOOG  Alphabet Inc. (Class C)  added  0001652044

# %%
sp500_history.sort_values(by=['date','ticker'], ascending=[True, True])
# Out:
#           date ticker                      name   action         cik
# 719 1957-03-04    ABT       Abbott Laboratories    added  0000001800
# 743 1957-03-04    ADM    Archer Daniels Midland    added  0000007084
# 730 1957-03-04    AEP   American Electric Power    added  0000004904
# 757 1957-03-04     BA                    Boeing    added  0000012927
# 760 1957-03-04    BMY      Bristol Myers Squibb    added  0000014272
# ..         ...    ...                       ...      ...         ...
# 2   2025-07-18    TTD          Trade Desk (The)    added         NaN
# 362 2025-07-23    HES          Hess Corporation  removed         NaN
# 1   2025-07-23    XYZ               Block, Inc.    added         NaN
# 0   2025-08-28   IBKR       Interactive Brokers    added         NaN
# 361 2025-08-28    WBA  Walgreens Boots Alliance  removed         NaN
#
# [993 rows x 5 columns]

# %%
sp500_history[sp500_history.ticker=='WBA']
# Out:
#           date ticker                      name   action  cik
# 361 2025-08-28    WBA  Walgreens Boots Alliance  removed  NaN

# %% [markdown]
# # yfinance 활용

# %%
pip install yfinance

# %%
import yfinance as yf

# %%
aapl = yf.download('AAPL', '1950-01-01', '2025-09-02', progress=True)
aapl
# Out:
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\2094929273.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   aapl = yf.download('AAPL', '1950-01-01', '2025-09-02', progress=True)
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 1980-12-12    0.098485    0.098913    0.098485    0.098485  469033600
# 1980-12-15    0.093347    0.093775    0.093347    0.093775  175884800
# 1980-12-16    0.086495    0.086924    0.086495    0.086924  105728000
# 1980-12-17    0.088636    0.089064    0.088636    0.088636   86441600
# 1980-12-18    0.091206    0.091634    0.091206    0.091206   73449600
# ...                ...         ...         ...         ...        ...
# 2025-08-25  227.160004  229.300003  226.229996  226.479996   30983100
# ...

# %%
aapl = yf.download('AAPL', '1950-01-01', '1979-09-02', progress=True)
aapl
# Out:
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\2798759814.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   aapl = yf.download('AAPL', '1950-01-01', '1979-09-02', progress=True)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: YFPricesMissingError('possibly delisted; no price data found  (1d 1950-01-01 -> 1979-09-02) (Yahoo error = "Data doesn\'t exist for startDate = -631134000, endDate = 305092800")')
# Empty DataFrame
# Columns: [(Adj Close, AAPL), (Close, AAPL), (High, AAPL), (Low, AAPL), (Open, AAPL), (Volume, AAPL)]
# Index: []

# %%
tickers = sp500_history.ticker.to_list()

# %%
stock_history = pd.DataFrame()

for ticker in tickers:
    # start = '1950-01-01'
    start = '2025-09-01'
    end = '2025-09-03'
    df = yf.download(ticker, start, end)
    stock_history = pd.concat([stock_history, df])

print(stock_history)
# Out:
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\714542062.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start, end)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\714542062.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start, end)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WBA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-09-01 -> 2025-09-03)')
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\714542062.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start, end)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ...

# %%
stock_history.index
# Out:
# DatetimeIndex(['2025-09-02', '2025-09-02', '2025-09-02', '2025-09-02',
#                '2025-09-02', '2025-09-02', '2025-09-02', '2025-09-02',
#                '2025-09-02', '2025-09-02',
#                ...
#                '2025-09-02', '2025-09-02', '2025-09-02', '2025-09-02',
#                '2025-09-02', '2025-09-02', '2025-09-02', '2025-09-02',
#                '2025-09-02', '2025-09-02'],
#               dtype='datetime64[ns]', name='Date', length=704, freq=None)

# %%
stock_history.columns
# Out:
# MultiIndex([(    'Close', 'IBKR'),
#             (     'High', 'IBKR'),
#             (      'Low', 'IBKR'),
#             (     'Open', 'IBKR'),
#             (   'Volume', 'IBKR'),
#             ('Adj Close',  'WBA'),
#             (    'Close',  'WBA'),
#             (     'High',  'WBA'),
#             (      'Low',  'WBA'),
#             (     'Open',  'WBA'),
#             ...
#             (    'Close',  'XEL'),
#             (     'High',  'XEL'),
#             (      'Low',  'XEL'),
#             (     'Open',  'XEL'),
#             (   'Volume',  'XEL'),
#             (    'Close',  'XOM'),
#             (     'High',  'XOM'),
#             (      'Low',  'XOM'),
#             (     'Open',  'XOM'),
#             (   'Volume',  'XOM')],
#            names=['Price', 'Ticker'], length=4490)

# %%
stock_history2 = pd.DataFrame()
dfs = []

for ticker in tickers:
    # start = '1950-01-01'
    start = '2024-01-01'
    end = '2025-09-03'
    df = yf.download(ticker, start, end)
    dfs.append(df)
    # stock_history2 = pd.concat([stock_history2, df])

print(stock_history2)
# Out:
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\829826007.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start, end)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\829826007.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start, end)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\829826007.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start, end)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\829826007.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start, end)
# ...

# %%
len(dfs[0])
# Out:
# 418

# %%
dfs
# Out:
# [Price           Close       High        Low       Open    Volume
#  Ticker           IBKR       IBKR       IBKR       IBKR      IBKR
#  Date
#  2024-01-02  20.704273  20.721414  20.143507  20.358997   4473200
#  2024-01-03  21.213612  21.424205  20.657744  20.704271   9136000
#  2024-01-04  21.353191  21.740096  21.218511  21.336050  10236400
#  2024-01-05  21.529503  21.970281  21.333603  21.397270   7671200
#  2024-01-08  21.463388  21.595622  21.003020  21.509914   5615600
#  ...               ...        ...        ...        ...       ...
#  2025-08-26  63.219337  64.417809  61.771184  64.417809  12322400
#  2025-08-27  61.711262  62.670038  61.082063  62.500256  98998600
#  2025-08-28  62.700001  62.879772  61.930981  62.400384   8207000
#  2025-08-29  62.240002  62.810001  61.639999  62.480000   6085000
#  2025-09-02  63.900002  63.910000  60.790001  61.299999   7339800
#
#  [418 rows x 5 columns],
#  Price           Close       High        Low       Open     Volume
# ...

# %%
dfs2 = []
for df in dfs:
    df = df.stack(level='Ticker').reset_index()
    df.columns.name = None
    dfs2.append(df)
# Out:
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\2916312157.py:3: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df = df.stack(level='Ticker').reset_index()
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\2916312157.py:3: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df = df.stack(level='Ticker').reset_index()
# ...

# %%
dfs[0]
# Out:
# Price           Close       High        Low       Open    Volume
# Ticker           IBKR       IBKR       IBKR       IBKR      IBKR
# Date
# 2024-01-02  20.704273  20.721414  20.143507  20.358997   4473200
# 2024-01-03  21.213612  21.424205  20.657744  20.704271   9136000
# 2024-01-04  21.353191  21.740096  21.218511  21.336050  10236400
# 2024-01-05  21.529503  21.970281  21.333603  21.397270   7671200
# 2024-01-08  21.463388  21.595622  21.003020  21.509914   5615600
# ...               ...        ...        ...        ...       ...
# 2025-08-26  63.219337  64.417809  61.771184  64.417809  12322400
# 2025-08-27  61.711262  62.670038  61.082063  62.500256  98998600
# 2025-08-28  62.700001  62.879772  61.930981  62.400384   8207000
# 2025-08-29  62.240002  62.810001  61.639999  62.480000   6085000
# 2025-09-02  63.900002  63.910000  60.790001  61.299999   7339800
#
# [418 rows x 5 columns]

# %%
dfs2[0]
# Out:
#           Date Ticker      Close       High        Low       Open    Volume
# 0   2024-01-02   IBKR  20.704273  20.721414  20.143507  20.358997   4473200
# 1   2024-01-03   IBKR  21.213612  21.424205  20.657744  20.704271   9136000
# 2   2024-01-04   IBKR  21.353191  21.740096  21.218511  21.336050  10236400
# 3   2024-01-05   IBKR  21.529503  21.970281  21.333603  21.397270   7671200
# 4   2024-01-08   IBKR  21.463388  21.595622  21.003020  21.509914   5615600
# ..         ...    ...        ...        ...        ...        ...       ...
# 413 2025-08-26   IBKR  63.219337  64.417809  61.771184  64.417809  12322400
# 414 2025-08-27   IBKR  61.711262  62.670038  61.082063  62.500256  98998600
# 415 2025-08-28   IBKR  62.700001  62.879772  61.930981  62.400384   8207000
# 416 2025-08-29   IBKR  62.240002  62.810001  61.639999  62.480000   6085000
# 417 2025-09-02   IBKR  63.900002  63.910000  60.790001  61.299999   7339800
#
# [418 rows x 7 columns]

# %%
stock_history3 = pd.concat(dfs2)

# %%
stock_history3[stock_history3['Adj Close'].isna()]
# Out:
#           Date Ticker       Close        High         Low        Open  \
# 0   2024-01-02   IBKR   20.704273   20.721414   20.143507   20.358997
# 1   2024-01-03   IBKR   21.213612   21.424205   20.657744   20.704271
# 2   2024-01-04   IBKR   21.353191   21.740096   21.218511   21.336050
# 3   2024-01-05   IBKR   21.529503   21.970281   21.333603   21.397270
# 4   2024-01-08   IBKR   21.463388   21.595622   21.003020   21.509914
# ..         ...    ...         ...         ...         ...         ...
# 413 2025-08-26    XOM  111.489998  111.809998  110.360001  111.370003
# 414 2025-08-27    XOM  112.750000  112.980003  111.419998  111.419998
# 415 2025-08-28    XOM  113.349998  113.650002  112.070000  112.870003
# 416 2025-08-29    XOM  114.290001  114.790001  113.580002  113.720001
# 417 2025-09-02    XOM  114.690002  115.239998  113.330002  114.180000
#
#          Volume  Adj Close
# 0     4473200.0        NaN
# 1     9136000.0        NaN
# 2    10236400.0        NaN
# ...

# %%
ToSQL(stock_history3, 'stock_history')
# Out:
# Error... : Can't reconnect until invalid transaction is rolled back.  Please rollback() fully before proceeding (Background on this error at: https://sqlalche.me/e/20/8s2b)

# %%
stock_history2
# Out:
# Price           Close       High        Low       Open      Volume Close High  \
# Ticker           IBKR       IBKR       IBKR       IBKR        IBKR   WBA  WBA
# Date
# 2024-01-02  20.704273  20.721414  20.143507  20.358997   4473200.0   NaN  NaN
# 2024-01-03  21.213612  21.424205  20.657744  20.704271   9136000.0   NaN  NaN
# 2024-01-04  21.353191  21.740096  21.218511  21.336050  10236400.0   NaN  NaN
# 2024-01-05  21.529503  21.970281  21.333603  21.397270   7671200.0   NaN  NaN
# 2024-01-08  21.463388  21.595622  21.003020  21.509914   5615600.0   NaN  NaN
# ...               ...        ...        ...        ...         ...   ...  ...
# 2025-08-26        NaN        NaN        NaN        NaN         NaN   NaN  NaN
# 2025-08-27        NaN        NaN        NaN        NaN         NaN   NaN  NaN
# 2025-08-28        NaN        NaN        NaN        NaN         NaN   NaN  NaN
# 2025-08-29        NaN        NaN        NaN        NaN         NaN   NaN  NaN
# ...

# %%
stock_history2 = pd.concat(dfs)

# %%
dfs[1]
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker            WBA        WBA        WBA        WBA        WBA
# Date
# 2024-01-02  24.634893  25.004648  23.950848  24.094128   12587840
# 2024-01-03  23.636557  24.408420  23.544118  24.385309   21928218
# 2024-01-04  22.425610  22.462584  20.872640  22.360903   60606675
# 2024-01-05  23.118902  23.118902  21.741567  22.333173   25916696
# 2024-01-08  23.692019  23.913873  22.647463  22.897048   24038235
# ...               ...        ...        ...        ...        ...
# 2025-08-22  12.070000  12.220000  12.070000  12.200000    9178662
# 2025-08-25  11.970000  12.175000  11.870000  12.080000   35998114
# 2025-08-26  11.920000  11.995000  11.880000  11.940000   90375653
# 2025-08-27  11.980000  12.110000  11.900000  11.915000  452081061
# 2025-08-28  11.980000  11.980000  11.980000  11.980000          0
#
# [416 rows x 5 columns]

# %% [markdown]
# # Function

# %%
stock_history2 = pd.DataFrame()
dfs = []

for ticker in tickers:
    # start = '1950-01-01'
    start = '2024-01-01'
    end = '2025-09-03'
    df = yf.download(ticker, start, end)
    dfs.append(df)
    # stock_history2 = pd.concat([stock_history2, df])

print(stock_history2)

dfs2 = []
for df in dfs:
    df = df.stack(level='Ticker').reset_index()
    df.columns.name = None
    dfs2.append(df)

# %%
def yfDownload(ticker_list, start, end):
    result = []
    for ticker in ticker_list:
        df = yf.download(ticker, start, end)
        df = df.stack(level='Ticker').reset_index()
        df.columns.name = None
        result.append(df)
    return result

# %%
import yfinance as yf
import pandas as pd

def yfDownload(ticker_list: list, start: str, end: str) -> pd.DataFrame:
    """
    주식 티커 목록의 데이터를 효율적으로 다운로드하여 단일 DataFrame으로 반환합니다.

    Args:
        ticker_list (list): 다운로드할 티커 목록
        start (str): 시작 날짜 (YYYY-MM-DD 형식)
        end (str): 끝 날짜 (YYYY-MM-DD 형식)

    Returns:
        pd.DataFrame: 모든 티커의 데이터를 포함하는 단일 DataFrame
    """
    
    # 1. 모든 티커의 데이터를 한 번에 다운로드
    # 이 방식이 for 루프보다 훨씬 빠릅니다.
    df_all_tickers = yf.download(ticker_list, start=start, end=end)
    
    # 2. 멀티인덱스를 가진 DataFrame을 단일 DataFrame으로 변환
    # Ticker 레벨을 행 인덱스로 옮기고 초기화하여 원하는 형식으로 만듭니다.
    df_long = df_all_tickers.stack().reset_index()
    
    # 3. 컬럼명 정리
    df_long.rename(columns={'level_0': 'Date', 'level_1': 'Ticker'}, inplace=True)
    df_long = df_long.sort_values(by=['Ticker','Date'], ascending=[True, True])
    df_long.columns.name = None
    
    return df_long

# %%
def ToSQL(df: pd.DataFrame, engine: create_engine, table_name: str, if_exists: str = 'replace'):
    """
    Pandas DataFrame을 SQL 데이터베이스 테이블에 저장합니다.
    트랜잭션을 안전하게 관리하여 오류를 방지합니다.

    Args:
        df (pd.DataFrame): 저장할 DataFrame
        engine (create_engine): SQLAlchemy 데이터베이스 엔진
        table_name (str): 데이터를 저장할 테이블 이름
        if_exists (str): 테이블 존재 시 처리 방법 ('fail', 'replace', 'append')
    """
    try:
        # with 구문을 사용하여 연결과 트랜잭션을 안전하게 관리
        with engine.connect() as conn:
            with conn.begin() as transaction:
                # 데이터 삽입
                df.to_sql(name=table_name, con=conn, if_exists=if_exists, index=False, chunksize=10000)
        
        print(f"Success: '{table_name}' 테이블에 데이터가 성공적으로 저장되었습니다.")
    
    except Exception as e:
        print(f"Error... : {e}")
        # with conn.begin()이 오류를 감지하면 자동으로 롤백을 수행합니다.
        # 따라서 명시적인 transaction.rollback() 호출은 필요하지 않습니다.

# %% [markdown]
# # 활용

# %%
res = yfDownload(tickers, '2020-01-01', '2020-01-03')
# Out:
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\2291717238.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start, end)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\2291717238.py:5: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df = df.stack(level='Ticker').reset_index()
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\2291717238.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start, end)
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
type(res)
# Out:
# list

# %%
len(tickers)
# Out:
# 993

# %%
res[5].head()
# Out:
#         Date Ticker   Close       High        Low       Open    Volume
# 0 2020-01-02    TTD  27.145  27.212799  26.105499  26.351999  22197000

# %%
len(dfs2)
# Out:
# 993

# %%
dfs2[990]
# Out:
#           Date Ticker       Close        High         Low        Open   Volume
# 0   2024-01-02    UNP  233.968811  236.429326  233.315247  235.458571  2622200
# 1   2024-01-03    UNP  232.306030  234.478202  231.614013  233.363283  1748200
# 2   2024-01-04    UNP  231.690903  234.593531  231.565951  231.863914  2305400
# 3   2024-01-05    UNP  230.585632  232.594399  229.143932  232.498279  2316900
# 4   2024-01-08    UNP  231.268021  231.316080  228.288515  229.874379  2567800
# ..         ...    ...         ...         ...         ...         ...      ...
# 413 2025-08-26    UNP  221.357574  221.606023  218.992341  221.178684  3758000
# 414 2025-08-27    UNP  219.578674  221.615954  219.042032  221.119057  3464900
# 415 2025-08-28    UNP  220.970001  223.464418  219.469363  222.878083  6299300
# 416 2025-08-29    UNP  223.570007  223.710007  221.199997  221.399994  5012800
# 417 2025-09-02    UNP  221.990005  222.770004  219.339996  222.210007  3955400
#
# [418 rows x 7 columns]

# %%
tmp = yfDownload(tickers, '2024-01-01', '2025-09-02')
# Out:
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\3946460718.py:19: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_all_tickers = yf.download(ticker_list, start=start, end=end)
# [*********************100%***********************]  854 of 854 completed
#
# 212 Failed downloads:
# ...

# %%
tmp
# Out:
#              Date Ticker  Adj Close       Close        High         Low  \
# 0      2024-01-02      A        NaN  137.212799  139.032410  136.382109
# 633    2024-01-03      A        NaN  129.706879  136.471095  129.617879
# 1266   2024-01-04      A        NaN  129.548660  130.043121  128.747637
# 1899   2024-01-05      A        NaN  129.113525  130.498024  127.195016
# 2532   2024-01-08      A        NaN  131.902298  132.090195  128.371842
# ...           ...    ...        ...         ...         ...         ...
# 262928 2025-08-25    ZTS        NaN  155.190002  157.210007  154.889999
# 263565 2025-08-26    ZTS        NaN  154.789993  156.320007  154.509995
# 264201 2025-08-27    ZTS        NaN  155.369995  156.110001  154.509995
# 264838 2025-08-28    ZTS        NaN  154.789993  155.350006  153.289993
# 265474 2025-08-29    ZTS        NaN  156.399994  156.490005  154.070007
#
#               Open     Volume
# 0       136.659006  1441600.0
# 633     136.471095  2074500.0
# ...

# %%
tmp.groupby(['Ticker']).count().sort_values(by=['Date'], ascending=[True])
# Out:
#         Date  Adj Close  Close  High  Low  Open  Volume
# Ticker
# PCL       19          0     19    19   19    19      19
# PCS       21          0     21    21   21    21      21
# FB        46          0     46    46   46    46      46
# SNDK     137          0    137   137  137   137     137
# INFO     222          0    222   222  222   222     222
# ...      ...        ...    ...   ...  ...   ...     ...
# AEE      417          0    417   417  417   417     417
# ADT      417          0    417   417  417   417     417
# ADSK     417          0    417   417  417   417     417
# ZTS      417          0    417   417  417   417     417
# A        417          0    417   417  417   417     417
#
# [642 rows x 7 columns]

# %%
tmp[tmp.Ticker=='PCL']
# Out:
#              Date Ticker  Adj Close      Close       High        Low  \
# 253799 2025-08-05    PCL        NaN  50.587002  50.587002  50.587002
# 254438 2025-08-06    PCL        NaN  50.521000  50.521000  50.521000
# 255077 2025-08-07    PCL        NaN  50.463001  50.463001  50.463001
# 255716 2025-08-08    PCL        NaN  50.238998  50.238998  50.238998
# 256355 2025-08-11    PCL        NaN  50.389999  50.389999  50.389999
# 256994 2025-08-12    PCL        NaN  50.389999  50.389999  50.389999
# 257633 2025-08-13    PCL        NaN  50.780998  50.780998  50.780998
# 258272 2025-08-14    PCL        NaN  50.501999  50.501999  50.501999
# 258911 2025-08-15    PCL        NaN  50.338001  50.338001  50.338001
# 259550 2025-08-18    PCL        NaN  50.222000  50.222000  50.222000
# 260189 2025-08-19    PCL        NaN  50.354000  50.354000  50.354000
# 260827 2025-08-20    PCL        NaN  50.375999  50.375999  50.375999
# 261465 2025-08-21    PCL        NaN  50.120998  50.120998  50.120998
# ...

# %%
tmp = yfDownload(tickers, '2020-01-01', '2020-01-31')
# Out:
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\2453470316.py:19: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_all_tickers = yf.download(ticker_list, start=start, end=end)
# [*********************100%***********************]  854 of 854 completed
#
# 236 Failed downloads:
# ...

# %%
tmp[tmp['Adj Close'].isna()==False]
# Out:
# Empty DataFrame
# Columns: [Date, Ticker, Adj Close, Close, High, Low, Open, Volume]
# Index: []

# %%
tmp
# Out:
#             Date Ticker  Adj Close       Close        High         Low  \
# 0     2020-01-02      A        NaN   82.711052   83.095980   81.989315
# 1     2020-01-02     AA        NaN   20.515049   20.936460   20.414485
# 2     2020-01-02    AAL        NaN   28.982893   29.192119   28.544513
# 3     2020-01-02    AAP        NaN  142.089020  143.461682  140.413290
# 4     2020-01-02   AAPL        NaN   72.538498   72.598876   71.292289
# ...          ...    ...        ...         ...         ...         ...
# 12320 2020-01-30    YUM        NaN   95.733208   95.778113   94.089756
# 12321 2020-01-30    ZBH        NaN  140.495316  140.541777  137.632991
# 12322 2020-01-30   ZBRA        NaN  246.320007  249.699997  243.339996
# 12323 2020-01-30   ZION        NaN   38.315544   38.356517   37.455166
# 12324 2020-01-30    ZTS        NaN  131.859406  132.145997  129.977473
#
#              Open       Volume
# 0       82.662941    1410500.0
# 1       20.936460    3062500.0
# ...

# %%
tickers[100:102]
# Out:
# ['KDP', 'ON']

# %%
len(tmp)
# Out:
# 2

# %%
res2 = yfDownload(tickers[:100], '2020-01-01', '2020-01-04')

# %%
stock_since_2000 = yfDownload(tickers, '2000-01-01', '2025-09-03')
# Out:
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\3946460718.py:19: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_all_tickers = yf.download(ticker_list, start=start, end=end)
# [*********************100%***********************]  854 of 854 completed
#
# 159 Failed downloads:
# ['CFN', 'ACAS', 'SPLS', 'BJS', 'WYN', 'KORS', 'JDSU', 'JOY', 'WFM', 'NVLS', 'Q', 'SWY', 'CMCSK', 'POM', 'PCLN', 'MIL', 'ARG', 'JOYG', 'EK', 'NYX', 'LVLT', 'GMCR', 'CVC', 'XTO', 'FNM', 'WLP', 'KFT', 'LEH', 'RAI', 'LO', 'TWC', 'AV', 'DJ', 'QTRN', 'BRCM', 'SNI', 'SIAL', 'FDO', 'CAM', 'FRE', 'MJN', 'BCR', 'LLTC', 'NOVL', 'BF.B', 'STJ', 'TYC', 'BS', 'HSP', 'MWW', 'LUK', 'JNS', 'PGN', 'TSO', 'CPGX', 'GGP', 'GENZ', 'LXK', 'SMS', 'KRFT', 'APOL', 'BXLT', 'LDW', 'DPS', 'CEPH', 'HCBK']: YFPricesMissingError('possibly delisted; no price data found  (1d 2000-01-01 -> 2025-09-03)')
# ...

# %%
stock_since_2000[stock_since_2000.Ticker=='AAPL']
# Out:
#               Date Ticker  Adj Close       Close        High         Low  \
# 2       2000-01-03   AAPL        NaN    0.840094    0.844316    0.763168
# 443     2000-01-04   AAPL        NaN    0.769266    0.830244    0.759415
# 885     2000-01-05   AAPL        NaN    0.780523    0.829775    0.773018
# 1327    2000-01-06   AAPL        NaN    0.712977    0.803038    0.712977
# 1769    2000-01-07   AAPL        NaN    0.746750    0.758008    0.716731
# ...            ...    ...        ...         ...         ...         ...
# 3631134 2025-08-26   AAPL        NaN  229.309998  229.490005  224.690002
# 3631771 2025-08-27   AAPL        NaN  230.490005  230.899994  228.259995
# 3632407 2025-08-28   AAPL        NaN  232.559998  233.410004  229.339996
# 3633044 2025-08-29   AAPL        NaN  232.139999  233.380005  231.369995
# 3633680 2025-09-02   AAPL        NaN  229.720001  230.850006  226.970001
#
#                Open       Volume
# 2          0.787090  535796800.0
# ...

# %%
stock_1990s = yfDownload(tickers, '1990-01-01', '1999-12-31')
stock_1980s = yfDownload(tickers, '1980-01-01', '1989-12-31')
stock_1970s = yfDownload(tickers, '1970-01-01', '1979-12-31')
stock_1960s = yfDownload(tickers, '1960-01-01', '1969-12-31')
# Out:
# C:\Users\fzaca\AppData\Local\Temp\ipykernel_25736\3946460718.py:19: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_all_tickers = yf.download(ticker_list, start=start, end=end)
# [*********************100%***********************]  853 of 854 completed
#
# 419 Failed downloads:
# ['CFN', 'ACAS', 'SPLS', 'WYN', 'KORS', 'JOY', 'NVLS', 'BS', 'Q', 'CMCSK', 'SWY', 'PCLN', 'MIL', 'JOYG', 'EK', 'NYX', 'BJS', 'GMCR', 'LVLT', 'CVC', 'XTO', 'CTX', 'FNM', 'WLP', 'KFT', 'RAI', 'LEH', 'TWC', 'LO', 'AV', 'DJ', 'QTRN', 'BRCM', 'SIAL', 'FDO', 'CAM', 'MJN', 'BCR', 'LLTC', 'NOVL', 'JDSU', 'BF.B', 'TYC', 'STJ', 'WFM', 'HSP', 'MWW', 'LUK', 'JNS', 'TSO', 'PGN', 'CPGX', 'GGP', 'GENZ', 'LXK', 'KRFT', 'APOL', 'LDW', 'BXLT', 'DPS', 'CEPH', 'HCBK']: YFPricesMissingError('possibly delisted; no price data found  (1d 1990-01-01 -> 1999-12-31)')
# ...

# %%
stock_1960s
# Out:
#             Date Ticker  Adj Close     Close      High       Low      Open  \
# 0     1962-01-02     AA        NaN  1.479800  1.488289  1.479800  1.479800
# 28    1962-01-03     AA        NaN  1.502434  1.502434  1.476969  1.479798
# 56    1962-01-04     AA        NaN  1.502434  1.513752  1.502434  1.502434
# 84    1962-01-05     AA        NaN  1.499605  1.510923  1.496776  1.502435
# 112   1962-01-08     AA        NaN  1.448676  1.493947  1.437359  1.493947
# ...          ...    ...        ...       ...       ...       ...       ...
# 58261 1969-12-23    XRX        NaN  6.642034  6.657924  6.546694  6.586419
# 58291 1969-12-24    XRX        NaN  6.594359  6.642029  6.554635  6.642029
# 58321 1969-12-26    XRX        NaN  6.562582  6.578472  6.530802  6.578472
# 58351 1969-12-29    XRX        NaN  6.443414  6.570534  6.419578  6.562589
# 58381 1969-12-30    XRX        NaN  6.586418  6.602308  6.419572  6.443408
#
#          Volume
# 0       55930.0
# 28      74906.0
# ...

# %%
stock_1970s
# Out:
#              Date Ticker  Adj Close     Close      High       Low      Open  \
# 0      1970-01-02     AA        NaN  1.912838  1.932903  1.912838  1.912838
# 30     1970-01-05     AA        NaN  1.892772  1.926213  1.889428  1.912837
# 60     1970-01-06     AA        NaN  1.872707  1.899460  1.872707  1.892772
# 90     1970-01-07     AA        NaN  1.862676  1.866020  1.859332  1.866020
# 120    1970-01-08     AA        NaN  1.855987  1.872707  1.849299  1.862675
# ...           ...    ...        ...       ...       ...       ...       ...
# 213931 1979-12-21    XRX        NaN  4.676716  4.762266  4.657705  4.743255
# 214045 1979-12-24    XRX        NaN  4.733752  4.733752  4.695730  4.695730
# 214159 1979-12-26    XRX        NaN  4.724247  4.752763  4.714741  4.733752
# 214273 1979-12-27    XRX        NaN  4.695729  4.733751  4.676718  4.724246
# 214387 1979-12-28    XRX        NaN  4.733752  4.733752  4.648202  4.695730
#
#           Volume
# 0        22971.0
# 30       25968.0
# ...

# %%
stock_1980s
# Out:
#              Date Ticker  Adj Close     Close      High       Low      Open  \
# 0      1980-01-02     AA        NaN  3.147815  3.154936  3.119328  3.126449
# 118    1980-01-03     AA        NaN  3.119329  3.147816  3.076598  3.147816
# 236    1980-01-04     AA        NaN  3.119329  3.126451  3.105085  3.119329
# 354    1980-01-07     AA        NaN  3.176302  3.176302  3.105085  3.119328
# 472    1980-01-08     AA        NaN  3.219032  3.240397  3.176301  3.176301
# ...           ...    ...        ...       ...       ...       ...       ...
# 632030 1989-12-22   ZION        NaN  1.608844  1.608844  1.608844  1.608844
# 632324 1989-12-26   ZION        NaN  1.608844  1.608844  1.608844  1.608844
# 632618 1989-12-27   ZION        NaN  1.675880  1.675880  1.630586  1.630586
# 632912 1989-12-28   ZION        NaN  1.675880  1.675880  1.630586  1.675880
# 633206 1989-12-29   ZION        NaN  1.675880  1.675880  1.630586  1.675880
#
#            Volume
# 0        302289.0
# ...

# %%
stock_1990s
# Out:
#              Date Ticker  Adj Close      Close       High        Low  \
# 895730 1999-11-18      A        NaN  26.399935  29.999927  23.999940
# 896163 1999-11-19      A        NaN  24.224941  25.799937  23.887442
# 896596 1999-11-22      A        NaN  26.399935  26.399935  24.037440
# 897029 1999-11-23      A        NaN  23.999947  26.174943  23.999947
# 897463 1999-11-24      A        NaN  24.637438  25.162437  23.999938
# ...           ...    ...        ...        ...        ...        ...
# 906595 1999-12-23   ZION        NaN  40.906239  41.672273  40.638127
# 907029 1999-12-27   ZION        NaN  36.961132  38.761312  35.850383
# 907463 1999-12-28   ZION        NaN  36.348309  36.999437  36.118498
# 907898 1999-12-29   ZION        NaN  36.405773  36.693036  36.003605
# 908333 1999-12-30   ZION        NaN  35.926979  36.578108  35.697169
#
#              Open      Volume
# 895730  27.299931  62546380.0
# 896163  25.762436  15234146.0
# 896596  24.787438   6577870.0
# ...

# %%
stock_since_2000
# Out:
#               Date Ticker  Adj Close       Close        High         Low  \
# 0       2000-01-03      A        NaN   43.199902   47.362390   40.424906
# 441     2000-01-04      A        NaN   39.899906   41.324903   38.849908
# 883     2000-01-05      A        NaN   37.424892   39.899887   36.187398
# 1325    2000-01-06      A        NaN   35.999901   37.199900   34.874904
# 1767    2000-01-07      A        NaN   38.999901   39.562399   35.399912
# ...            ...    ...        ...         ...         ...         ...
# 3631766 2025-08-26    ZTS        NaN  154.789993  156.320007  154.509995
# 3632402 2025-08-27    ZTS        NaN  155.369995  156.110001  154.509995
# 3633039 2025-08-28    ZTS        NaN  154.789993  155.350006  153.289993
# 3633675 2025-08-29    ZTS        NaN  156.399994  156.490005  154.070007
# 3634310 2025-09-02    ZTS        NaN  152.880005  155.380005  151.610001
#
#                Open     Volume
# 0         47.249890  4674353.0
# ...
